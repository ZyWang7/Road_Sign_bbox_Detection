# %% [markdown]
# ## Visualize the prediction

# %%
import matplotlib.pyplot as plt
import glob
import random
import os

# Plot and visualize images in a 2x2 grid.
def visualize(result_dir, num_samples=4):
    """
    Function accepts a list of images and plots
    them in a 2x2 grid.
    """
    plt.figure(figsize=(8, 8))
    image_names = glob.glob(os.path.join(result_dir, '*.png'))
    random.shuffle(image_names)
    for i, image_name in enumerate(image_names):
        image = plt.imread(image_name)
        plt.subplot(2, 2, i+1)
        plt.imshow(image)
        plt.axis('off')
        if i == num_samples-1:
            break
    plt.tight_layout()
    plt.show()

# %%
visualize('runs/detect/yolov8_100e_infer/')

# %% [markdown]
# ## Make predictions on custom image

# %%
from ultralytics import YOLO

model = YOLO('runs/detect/road_sign_yolov8_100e/weights/best.pt')

# Run inference on 'bus.jpg' with arguments
model.predict('trafficlight.jpg', save=True, imgsz=640, conf=0.3)
# Out:
# image 1/1 /Users/wzy/Desktop/GitHub/Road_Sign_bbox_Detection/trafficlight.jpg: 448x640 1 trafficlight, 48.6ms
# Speed: 2.7ms preprocess, 48.6ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'speedlimit', 1: 'stop', 2: 'crosswalk', 3: 'trafficlight'}
#  orig_img: array([[[225, 205, 200],
#          [225, 205, 200],
#          [225, 205, 200],
#          ...,
#          [234, 187, 160],
#          [234, 187, 160],
#          [234, 187, 160]],
#
#         [[225, 205, 200],
#          [225, 205, 200],
#          [225, 205, 200],
#          ...,
#          [234, 187, 160],
#          [234, 187, 160],
#          [234, 187, 160]],
#
#         [[225, 205, 200],
#          [225, 205, 200],
#          [225, 205, 200],
#          ...,
# ...

# %%
import matplotlib.pyplot as plt
from PIL import Image

image = Image.open("runs/detect/predict/trafficlight.jpg")
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 5183.5, 3455.5, -0.5)

# %%
model.predict('speedlimit.png', save=True, imgsz=640)
# Out:
# image 1/1 /Users/wzy/Desktop/GitHub/Road_Sign_bbox_Detection/speedlimit.png: 320x640 2 speedlimits, 37.0ms
# Speed: 1.4ms preprocess, 37.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'speedlimit', 1: 'stop', 2: 'crosswalk', 3: 'trafficlight'}
#  orig_img: array([[[248, 222, 196],
#          [248, 222, 196],
#          [248, 222, 196],
#          ...,
#          [139, 134, 129],
#          [153, 148, 142],
#          [157, 150, 145]],
#
#         [[248, 222, 196],
#          [248, 222, 196],
#          [248, 222, 196],
#          ...,
#          [ 94,  87,  82],
#          [103,  97,  92],
#          [107, 100,  94]],
#
#         [[248, 222, 196],
#          [248, 222, 196],
#          [248, 222, 196],
#          ...,
#          [ 70,  62,  57],
# ...

# %%
image = Image.open("runs/detect/predict/speedlimit.png")
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 2399.5, 1175.5, -0.5)

# %%
model.predict('stop.png', save=True, imgsz=640)
# Out:
# image 1/1 /Users/wzy/Desktop/GitHub/Road_Sign_bbox_Detection/stop.png: 640x576 1 stop, 54.4ms
# Speed: 2.2ms preprocess, 54.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'speedlimit', 1: 'stop', 2: 'crosswalk', 3: 'trafficlight'}
#  orig_img: array([[[128,  77,  51],
#          [127,  77,  51],
#          [128,  77,  51],
#          ...,
#          [139,  90,  65],
#          [138,  90,  65],
#          [140,  91,  65]],
#
#         [[128,  79,  52],
#          [127,  77,  51],
#          [127,  77,  50],
#          ...,
#          [139,  91,  66],
#          [139,  91,  65],
#          [140,  91,  66]],
#
#         [[129,  79,  52],
#          [129,  79,  53],
#          [128,  78,  53],
#          ...,
#          [140,  92,  67],
# ...

# %%
image = Image.open("runs/detect/predict/stop.png")
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 1393.5, 1605.5, -0.5)

# %%
model.predict('crosswalk.jpg', save=True, imgsz=640)
# Out:
# image 1/1 /Users/wzy/Desktop/GitHub/Road_Sign_bbox_Detection/crosswalk.jpg: 480x640 1 crosswalk, 63.4ms
# Speed: 2.8ms preprocess, 63.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'speedlimit', 1: 'stop', 2: 'crosswalk', 3: 'trafficlight'}
#  orig_img: array([[[ 24,  27,  18],
#          [ 23,  26,  17],
#          [ 23,  26,  17],
#          ...,
#          [251, 221, 192],
#          [251, 221, 192],
#          [251, 221, 192]],
#
#         [[ 23,  26,  17],
#          [ 23,  26,  17],
#          [ 23,  26,  17],
#          ...,
#          [251, 221, 192],
#          [251, 221, 192],
#          [251, 221, 192]],
#
#         [[ 23,  26,  17],
#          [ 23,  26,  17],
#          [ 23,  26,  17],
#          ...,
#          [251, 221, 192],
# ...

# %%
image = Image.open("runs/detect/predict/crosswalk.jpg")
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 1299.5, 956.5, -0.5)
